# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/Datasets/esewa_reviews.csv'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#    Unnamed: 0                              reviewId       userName  \
# 0           0  bf9a3185-608d-4293-bfea-3f5157e3b426  A Google user
# 1           1  7e8ef74b-dbaa-4afd-8174-2d1ecd194b8c  A Google user
# 2           2  4cba7404-d8b4-48c9-ba5b-8a0b14764a2f  A Google user
# 3           3  ac7b0fa4-94b9-40e9-9d57-ea7f3273406b  A Google user
# 4           4  0339aa75-24d4-41cb-8471-a69b39e9f3ae  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                                            AjayDas      5              1
# 1                                 Useless, very slow      1              0
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['reviewId', 'userName', 'userImage', 'content', 'score',
#        'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent',
#        'repliedAt', 'appVersion', 'clean_text', 'tokens'],
#       dtype='object')

# %%
df.head(1)
# Out:
#                                reviewId       userName  \
# 0  bf9a3185-608d-4293-bfea-3f5157e3b426  A Google user
#
#                                            userImage  content  score  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...  AjayDas      5
#
#    thumbsUpCount reviewCreatedVersion                   at  \
# 0              1                  NaN  2022-08-15 21:16:51
#
#                                         replyContent            repliedAt  \
# 0  Hello Ajay Sir, thank you so much for your enc...  2022-08-16 09:35:32
#
#   appVersion clean_text       tokens
# 0        NaN    ajaydas  ['ajaydas']

# %%
df['content'].head()
# Out:
# 0                                              AjayDas
# 1                                   Useless, very slow
# 2    Such a poor app. Transaction limit got decreas...
# 3                                           Not update
# 4    Totally frustrating application. Can't even lo...
# Name: content, dtype: object

# %%
df.isna().sum()
# Out:
# reviewId                   0
# userName                   0
# userImage                  0
# content                    0
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion    3082
# at                         0
# replyContent            5398
# repliedAt               5398
# appVersion              3082
# clean_text               193
# tokens                     0
# dtype: int64

# %%
columns = ['reviewCreatedVersion', 'replyContent', 'repliedAt', 'appVersion', 'clean_text', 'tokens']
df.drop(columns=columns, axis=1, inplace=True)

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  bf9a3185-608d-4293-bfea-3f5157e3b426  A Google user
# 1  7e8ef74b-dbaa-4afd-8174-2d1ecd194b8c  A Google user
# 2  4cba7404-d8b4-48c9-ba5b-8a0b14764a2f  A Google user
# 3  ac7b0fa4-94b9-40e9-9d57-ea7f3273406b  A Google user
# 4  0339aa75-24d4-41cb-8471-a69b39e9f3ae  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                                            AjayDas      5              1
# 1                                 Useless, very slow      1              0
# 2  Such a poor app. Transaction limit got decreas...      1              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewId       10000 non-null  object
#  1   userName       10000 non-null  object
#  2   userImage      10000 non-null  object
#  3   content        10000 non-null  object
#  4   score          10000 non-null  int64
#  5   thumbsUpCount  10000 non-null  int64
#  6   at             10000 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 547.0+ KB

# %%
df['at'] = pd.to_datetime(df['at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewId       10000 non-null  object
#  1   userName       10000 non-null  object
#  2   userImage      10000 non-null  object
#  3   content        10000 non-null  object
#  4   score          10000 non-null  int64
#  5   thumbsUpCount  10000 non-null  int64
#  6   at             10000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 547.0+ KB

# %%
df.isna().sum()
# Out:
# reviewId         0
# userName         0
# userImage        0
# content          0
# score            0
# thumbsUpCount    0
# at               0
# dtype: int64

# %%
df['score'].unique()
# Out:
# array([5, 1, 3, 2, 4])

# %%
# 3. Score → Emotion Mapping
def score_to_emotion(score):
    if score == 1:
        return "angry"
    elif score == 2:
        return "sad"
    elif score == 3:
        return "neutral"
    elif score == 4:
        return "happy"
    elif score == 5:
        return "excited"

df['emotion'] = df['score'].apply(score_to_emotion)

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import re
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
def preprocess(text):
    text = text.lower()
    text = re.sub(r"http\S+|@\S+|#\S+|[^a-z\s]", "", text)
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(t) for t in tokens if t not in stopwords.words('english')]
    return " ".join(tokens)

# %%
df['clean_text'] = df['content'].apply(preprocess)

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  bf9a3185-608d-4293-bfea-3f5157e3b426  A Google user
# 1  7e8ef74b-dbaa-4afd-8174-2d1ecd194b8c  A Google user
# 2  4cba7404-d8b4-48c9-ba5b-8a0b14764a2f  A Google user
# 3  ac7b0fa4-94b9-40e9-9d57-ea7f3273406b  A Google user
# 4  0339aa75-24d4-41cb-8471-a69b39e9f3ae  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                                            AjayDas      5              1
# 1                                 Useless, very slow      1              0
# 2  Such a poor app. Transaction limit got decreas...      1              0
# ...

# %% [markdown]
# #Encode Labels and Tokenize Text

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Label Encoding
le = LabelEncoder()
df['label'] = le.fit_transform(df['emotion'])

# Tokenization
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(df['clean_text'])
sequences = tokenizer.texts_to_sequences(df['clean_text'])
padded = pad_sequences(sequences, padding='post', maxlen=100)

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  bf9a3185-608d-4293-bfea-3f5157e3b426  A Google user
# 1  7e8ef74b-dbaa-4afd-8174-2d1ecd194b8c  A Google user
# 2  4cba7404-d8b4-48c9-ba5b-8a0b14764a2f  A Google user
# 3  ac7b0fa4-94b9-40e9-9d57-ea7f3273406b  A Google user
# 4  0339aa75-24d4-41cb-8471-a69b39e9f3ae  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                                            AjayDas      5              1
# 1                                 Useless, very slow      1              0
# 2  Such a poor app. Transaction limit got decreas...      1              0
# ...

# %% [markdown]
# #Build and Train LSTM Model

# %%
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout


model = Sequential([
    Embedding(input_dim=10000, output_dim=128, input_length=100),
    Bidirectional(LSTM(64, return_sequences=True)),
    Dropout(0.3),
    Bidirectional(LSTM(32)),
    Dense(32, activation='relu'),
    Dense(len(le.classes_), activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# 9. Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    padded, df['label'], test_size=0.2, random_state=42
)

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ...

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',   # monitor validation loss
    patience=3,           # number of epochs to wait before stopping if no improvement
    restore_best_weights=True
)

model.fit(
    X_train, y_train,
    epochs=20,                    # Increase max epochs to let early stopping decide
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 72s 288ms/step - accuracy: 0.7209 - loss: 0.8836 - val_accuracy: 0.7145 - val_loss: 0.8749
# Epoch 2/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 73s 252ms/step - accuracy: 0.7553 - loss: 0.7682 - val_accuracy: 0.7105 - val_loss: 0.8940
# Epoch 3/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 256ms/step - accuracy: 0.7838 - loss: 0.6973 - val_accuracy: 0.7110 - val_loss: 0.9324
# Epoch 4/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 261ms/step - accuracy: 0.7961 - loss: 0.6481 - val_accuracy: 0.7065 - val_loss: 0.9793

# %%
print(df['emotion'].value_counts())
# Out:
# emotion
# excited    5054
# angry      3332
# happy       677
# neutral     537
# sad         400
# Name: count, dtype: int64

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy*100:.2f}%")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.7114 - loss: 0.8745
# Test Accuracy: 71.45%

# %%
def predict_emotion(text):
    cleaned = preprocess(text)
    seq = tokenizer.texts_to_sequences([cleaned])
    padded_seq = pad_sequences(seq, maxlen=100, padding='post')
    pred = model.predict(padded_seq)
    label = le.inverse_transform([np.argmax(pred)])
    return label[0]

# %%
# 12. Test
print(predict_emotion("I am very disappointed with your customer support."))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 893ms/step
# angry

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy*100:.2f}%")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 116ms/step - accuracy: 0.2673 - loss: 1.6051
# Test Accuracy: 27.80%

# %%
def preprocess(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    return text

def predict_emotion(text):
    cleaned = preprocess(text)
    seq = tokenizer.texts_to_sequences([cleaned])
    padded_seq = pad_sequences(seq, maxlen=100, padding='post')
    pred = model.predict(padded_seq)
    label = le.inverse_transform([np.argmax(pred)])
    return label[0]

# %%
print(predict_emotion("I am very disappointed with your customer support."))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 885ms/step
# angry
